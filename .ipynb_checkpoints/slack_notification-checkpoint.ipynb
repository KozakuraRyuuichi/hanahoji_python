# %%
from slacker import Slacker
 
def main():
    # APIトークンを指定
    token = 'xoxb-1416141106465-1389788588327-nK5jk6j2zjCU43KO5blbDIyB'
    # アップロードするチャンネルを指定
    channel = "#" + "random"
    # 絶対パスを指定
    file = '/Users/kozakuraryuuichi/hanahoji/outputs/test.jpg'
 
    slacker = Slacker(token)
    slacker.files.upload(file_=file, channels=channel)
#     slacker.chat.post_message(channel, 'https://www.youtube.com/watch?v=WKfolJv6Kx8')
 
if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# ...
